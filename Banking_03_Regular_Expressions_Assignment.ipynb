# %% [markdown]
# <a href="https://colab.research.google.com/github/yuvids2050/class-practice/blob/main/Banking_03_Regular_Expressions_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Banking Assignment — Regular Expressions (100 Questions with Hints)
#
# An unsolved assessment notebook using accounts, deposits, withdrawals, transfers, cards, loans, KYC, fraud monitoring, reconciliation, and audit trails.
#
# **Structure:** 30 easy + 40 medium + 30 difficult = **100 questions**.

# %% [markdown]
# ## Student instructions
#
# Solve all questions using banking scenarios. Practice literal matching, character classes, anchors, quantifiers, groups, alternation, extraction, substitution, lookarounds, backreferences, compilation, flags, validation, and safe text pipelines. Do not store real customer data, credentials, PINs, or complete card numbers. Each question includes a graduated hint but intentionally has no solution.
#
# **Recommended workflow:** write assumptions, implement the smallest correct function/class, test normal and edge cases, then explain your design.

# %% [markdown]
# ---
#
# ## Easy
#
# Fundamentals and direct applications.

# %% [markdown]
# ### Q1. Find a account code for banking case 1; use sample reference `ACC-1001` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Customer account references: ACC-1001, ACC-2045, ACC-9999"

pattern = r"\bACC-\d{4}"

matches = re.findall(pattern, text)

print("Account codes", matches)
print("Sample reference found:", "ACC-1001" in matches)
# Out:
# Account codes ['ACC-1001', 'ACC-2045', 'ACC-9999']
# Sample reference found: True

# %% [markdown]
# ### Q2. Validate a six-digit pin for banking case 1; use sample reference `ACC-1002` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

pin = "482951"

pattern = r"\d{6}"

if re.findall(pattern , pin):
  print("valid six-digit pin")

else:
  print("Invalid pin")
# Out:
# valid six-digit pin

# %% [markdown]
# ### Q3. Extract all amounts for banking case 1; use sample reference `ACC-1003` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Deposit ₹15000, withdrawal ₹2500.50 and transfer ₹8000."

pattern = r"\d+(?:\.\d+)?"

amounts = re.findall(pattern,text)

print("Amounts:", amounts)
# Out:
# Amounts: ['15000', '2500.50', '8000']

# %% [markdown]
# ### Q4. Match a receipt date for banking case 1; use sample reference `ACC-1004` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Receipt generated on 31/08/2026."

pattern = r"\b\d{2}/\d{2}/\d{4}\b"

match = re.search(pattern, text)

if match:
    print("Receipt date:", match.group())
else:
    print("No valid date found")
# Out:
# Receipt date: 31/08/2026

# %% [markdown]
# ### Q5. Find uppercase account references for banking case 1; use sample reference `ACC-1005` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Accounts: ACC-1005, acc-2005, ACC-3007, Acc-4008"

pattern = r"\bACC-\d{4}\b"

matches = re.findall(pattern, text)

print("Uppercase account references:", matches)
# Out:
# Uppercase account references: ['ACC-1005', 'ACC-3007']

# %% [markdown]
# ### Q6. Remove extra spaces for banking case 1; use sample reference `ACC-1006` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "ACC-1006    Rahul     Savings     Account"

cleaned = re.sub(r"\s+", " ",text).strip()

print("original:", text)
print("Cleaned:", cleaned)
# Out:
# original: ACC-1006    Rahul     Savings     Account
# Cleaned: ACC-1006 Rahul Savings Account

# %% [markdown]
# ### Q7. Split a comma-separated tag list for banking case 1; use sample reference `ACC-1007` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "savings,deposit,priority,verified"

tags = re.split(r"\s*,\s*", text)

print("Tags:", tags)
# Out:
# Tags: ['savings', 'deposit', 'priority', 'verified']

# %% [markdown]
# ### Q8. Check a phone number for banking case 1; use sample reference `ACC-1008` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

phone = "9876543210"

pattern = r"\d{10}"

if re.fullmatch(pattern, phone):
    print("Valid phone number")
else:
    print("Invalid phone number")
# Out:
# Valid phone number

# %% [markdown]
# ### Q9. Find fee waiver codes for banking case 1; use sample reference `ACC-1009` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Available codes: FEEWAIVE10, CASHBACK20, FEEWAIVE25"

pattern = r"\bFEEWAIVE\d{2}\b"

matches = re.findall(pattern, text)

print("Fee waiver codes:", matches)
# Out:
# Fee waiver codes: ['FEEWAIVE10', 'FEEWAIVE25']

# %% [markdown]
# ### Q10. Replace masked card digits for banking case 1; use sample reference `ACC-1010` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Card number: 4321-XXXX-XXXX-7890"

pattern = r"X+"

result = re.sub(pattern, "****", text)

print(result)
# Out:
# Card number: 4321-****-****-7890

# %% [markdown]
# ### Q11. Extract quantities for banking case 1; use sample reference `ACC-1011` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Account ACC-1011 has 5 deposits and 12 withdrawals."

pattern = r"\b\d+\b"

quantities = re.findall(pattern, text)

print("Quantities:", quantities)
# Out:
# Quantities: ['1011', '5', '12']

# %% [markdown]
# ### Q12. Match branch ids for banking case 1; use sample reference `ACC-1012` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Branches: BR-1024, BR-2045, BR-9999"


pattern = r"\bBR-\d{4}\b"

matches = re.findall(pattern , text)

print("Branch IDs:", matches)
# Out:
# Branch IDs: ['BR-1024', 'BR-2045', 'BR-9999']

# %% [markdown]
# ### Q13. Find email addresses for banking case 1; use sample reference `ACC-1013` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here


import re

text = """
Customer contact:
rahul@example.com
support@bank.com
admin123@finance.org
"""

pattern = r"\b[\w.+-]+@[\w.-]+\.[A-Za-z]{2,}\b"

emails = re.findall(pattern, text)

print("Email addresses:", emails)
# Out:
# Email addresses: ['rahul@example.com', 'support@bank.com', 'admin123@finance.org']

# %% [markdown]
# ### Q14. Validate a postcode for banking case 1; use sample reference `ACC-1014` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

postcode = "560001"

pattern = r"\d{6}"

if re.fullmatch(pattern, postcode):
    print("Valid postcode")
else:
    print("Invalid postcode")
# Out:
# Valid postcode

# %% [markdown]
# ### Q15. Detect the word sale for banking case 1; use sample reference `ACC-1015` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "The bank announced a special SALE offer for customers."

pattern = r"\bsale\b"

matches = re.search(pattern, text, re.IGNORECASE)

if match:
  print("The word 'sale' was found")
else:
  print("The word 'sale' was not found")
# Out:
# The word 'sale' was found

# %% [markdown]
# ### Q16. Find a account code for banking case 2; use sample reference `ACC-1016` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Transactions belong to ACC-1016, ACC-2022 and ACC-3045."

pattern = r"\bACC-\d{4}\b"

matches = re.findall(pattern, text)

print("Account codes:", matches)
print("Sample reference found:", "ACC-1016" in matches)
# Out:
# Account codes: ['ACC-1016', 'ACC-2022', 'ACC-3045']
# Sample reference found: True

# %% [markdown]
# ### Q17. Validate a six-digit pin for banking case 2; use sample reference `ACC-1017` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

pin = "731604"

pattern = r"\d{6}"

if re.fullmatch(pattern, pin):
    print("Valid six-digit PIN")
else:
    print("Invalid PIN")
# Out:
# Valid six-digit PIN

# %% [markdown]
# ### Q18. Extract all amounts for banking case 2; use sample reference `ACC-1018` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Deposit ₹20000, service charge ₹350.75 and transfer ₹9500."

pattern = r"\d+(?:\.\d+)?"

amounts = re.findall(pattern, text)

print("Amounts:", amounts)
# Out:
# Amounts: ['20000', '350.75', '9500']

# %% [markdown]
# ### Q19. Match a receipt date for banking case 2; use sample reference `ACC-1019` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Transaction receipt date: 15/09/2026."

pattern = r"\b\d{2}/\d{2}/\d{4}\b"

match = re.search(pattern, text)

if match:
  print("Receipt date:", match.group())

else:
  print("No receipt date found")
# Out:
# Receipt date: 15/09/2026

# %% [markdown]
# ### Q20. Find uppercase account references for banking case 2; use sample reference `ACC-1020` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "References: ACC-1020, acc-2020, ACC-3030, acc-4040"

pattern = r"\bACC-\d{4}\b"

matches = re.findall(pattern, text)

print("Uppercase account references:", matches)
# Out:
# Uppercase account references: ['ACC-1020', 'ACC-3030']

# %% [markdown]
# ### Q21. Remove extra spaces for banking case 2; use sample reference `ACC-1021` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "ACC-1021    Rahul     Savings      Account"

cleaned = re.sub(r"\s+", " ", text).strip()

print("Original:", text)
print("Cleaned:", cleaned)
# Out:
# Original: ACC-1021    Rahul     Savings      Account
# Cleaned: ACC-1021 Rahul Savings Account

# %% [markdown]
# ### Q22. Split a comma-separated tag list for banking case 2; use sample reference `ACC-1022` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "savings, deposit, priority, verified"

tags = re.split(r"\s*,\s*", text)

print("Tags:", tags)
# Out:
# Tags: ['savings', 'deposit', 'priority', 'verified']

# %% [markdown]
# ### Q23. Check a phone number for banking case 2; use sample reference `ACC-1023` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

phone = "9845543210"

pattern = r"\d{10}"

if re.fullmatch(pattern, phone):
    print("Valid phone number")
else:
    print("Invalid phone number")
# Out:
# Valid phone number

# %% [markdown]
# ### Q24. Find fee waiver codes for banking case 2; use sample reference `ACC-1024` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Codes: FEEWAIVE10, CASHBACK20, FEEWAIVE25"

pattern = r"\bFEEWAIVE\d{2}\b"

matches = re.findall(pattern , text)

print("Fee waiver codes:", matches)
# Out:
# Fee waiver codes: ['FEEWAIVE10', 'FEEWAIVE25']

# %% [markdown]
# ### Q25. Replace masked card digits for banking case 2; use sample reference `ACC-1025` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Card: 4321-XXXX-XXXX-7890"

result = re.sub(r"X+", "****", text)

print(result)
# Out:
# Card: 4321-****-****-7890

# %% [markdown]
# ### Q26. Extract quantities for banking case 2; use sample reference `ACC-1026` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "ACC-1026 has 9 deposits and 15 withdrawals."

pattern = r"\b\d+\b"

numbers = re.findall(pattern, text)

print("Numbers found:", numbers)
# Out:
# Numbers found: ['1026', '9', '15']

# %% [markdown]
# ### Q27. Match branch ids for banking case 2; use sample reference `ACC-1027` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Branches: BR-1024, BR-2045, BR-9999"

pattern = r"\bBR-\d{4}\b"

matches = re.findall(pattern, text)

print("Branch IDs:", matches)
# Out:
# Branch IDs: ['BR-1024', 'BR-2045', 'BR-9999']

# %% [markdown]
# ### Q28. Find email addresses for banking case 2; use sample reference `ACC-1028` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = """
Customer emails:
rahul@example.com
support@bank.com
admin123@finance.org
"""

pattern = r"\b[\w.+-]+@[\w.-]+\.[A-Za-z]{2,}\b"

emails = re.findall(pattern, text)

print("Email Addresses:", emails)
# Out:
# Email Addresses: ['rahul@example.com', 'support@bank.com', 'admin123@finance.org']

# %% [markdown]
# ### Q29. Validate a postcode for banking case 2; use sample reference `ACC-1029` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

postcode = "560001"

pattern = r"\d{6}"

if re.fullmatch(pattern, postcode):
    print("Valid postcode")
else:
    print("Invalid postcode")
# Out:
# Valid postcode

# %% [markdown]
# ### Q30. Detect the word sale for banking case 2; use sample reference `ACC-1030` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Customers can receive a special SALE offer today."

pattern = r"\bsale\b"

match = re.search(pattern, text, re.IGNORECASE)

if match:
    print("The word 'sale' was found")
else:
    print("The word 'sale' was not found")
# Out:
# The word 'sale' was found

# %% [markdown]
# ---
#
# ## Medium
#
# Reusable components and multi-step workflows.

# %% [markdown]
# ### Q31. Parse a receipt line into named groups for banking case 1; use sample reference `ACC-1031` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "SAV123 | 4 | 1250.50"

pattern = re.compile(
    r"^(?P<account>[A-Z]{3}\d{3})\s*\|\s*"
    r"(?P<quantity>\d+)\s*\|\s*"
    r"(?P<amount>\d+(?:\.\d{2})?)$"
)

match = pattern.fullmatch(text)

if match:
    print("Parsed data:")
    print(match.groupdict())
else:
    print("Invalid receipt line")
# Out:
# Parsed data:
# {'account': 'SAV123', 'quantity': '4', 'amount': '1250.50'}

# %% [markdown]
# ### Q32. Validate an account reference with optional category prefix for banking case 1; use sample reference `ACC-1032` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

pattern = r"(?:SAV-|CUR-)?ACC-\d{4}"

references = [
    "ACC-1032",
    "SAV-ACC-1032",
    "CUR-ACC-1032",
    "LOAN-ACC-1032"
]

for reference in references:
    if re.fullmatch(pattern, reference):
        print(reference, "-> Valid")
    else:
        print(reference, "-> Invalid")
# Out:
# ACC-1032 -> Valid
# SAV-ACC-1032 -> Valid
# CUR-ACC-1032 -> Valid
# LOAN-ACC-1032 -> Invalid

# %% [markdown]
# ### Q33. Extract currency and amount for banking case 1; use sample reference `ACC-1033` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Transaction amount: ₹12500.50"

pattern = r"(?P<currency>₹|\$|€|£)\s*(?P<amount>\d+(?:\.\d{2})?)"

match = re.search(pattern, text)

if match:
    print("Currency:", match.group("currency"))
    print("Amount:", match.group("amount"))
else:
    print("No currency amount found")
# Out:
# Currency: ₹
# Amount: 12500.50

# %% [markdown]
# ### Q34. Normalize account holder phone numbers for banking case 1; use sample reference `ACC-1034` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

phones = [
    "+91 98765 43210",
    "09876543210",
    "98765-43210",
    "+91-98765-43210"
]

for phone in phones:
    digits = re.sub(r"\D", "", phone)

    if digits.startswith("91") and len(digits) == 12:
        digits = digits[2:]
    elif digits.startswith("0") and len(digits) == 11:
        digits = digits[1:]

    print(phone, "->", digits)
# Out:
# +91 98765 43210 -> 9876543210
# 09876543210 -> 9876543210
# 98765-43210 -> 9876543210
# +91-98765-43210 -> 9876543210

# %% [markdown]
# ### Q35. Find repeated account words for banking case 1; use sample reference `ACC-1035` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "The account account was reviewed and the transfer transfer was approved."

pattern = r"\b(\w+)\s+\1\b"

matches = re.findall(pattern, text, re.IGNORECASE)

print("Repeated words:", matches)
# Out:
# Repeated words: ['account', 'transfer']

# %% [markdown]
# ### Q36. Validate fee waiver start and end anchors for banking case 1; use sample reference `ACC-1036` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

tokens = [
    "FEEWAIVE10",
    "FEEWAIVE25",
    "X-FEEWAIVE10",
    "FEEWAIVE10-EXTRA"
]

pattern = r"^FEEWAIVE\d{2}$"

for token in tokens:
    if re.fullmatch(pattern, token):
        print(token, "-> Valid")
    else:
        print(token, "-> Invalid")
# Out:
# FEEWAIVE10 -> Valid
# FEEWAIVE25 -> Valid
# X-FEEWAIVE10 -> Invalid
# FEEWAIVE10-EXTRA -> Invalid

# %% [markdown]
# ### Q37. Redact emails from support text for banking case 1; use sample reference `ACC-1037` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = """
Customer email: rahul@example.com
Backup email: support@bank.com
"""

pattern = r"\b[\w.+-]+@[\w.-]+\.[A-Za-z]{2,}\b"

redacted = re.sub(pattern, "[REDACTED_EMAIL]", text)

print(redacted)
# Out:
# Customer email: [REDACTED_EMAIL]
# Backup email: [REDACTED_EMAIL]

# %% [markdown]
# ### Q38. Extract transfer ids without partial matches for banking case 1; use sample reference `ACC-1038` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
import re

text = """
Transfer TR-1001 completed.
Invalid partial text XTR-1002.
Transfer TR-2030 completed.
"""

pattern = r"\bTR-\d{4}\b"

matches = re.findall(pattern, text)

print("Transfer IDs:", matches)# Write your solution here
# Out:
# Transfer IDs: ['TR-1001', 'TR-2030']

# %% [markdown]
# ### Q39. Parse inventory key-value pairs for banking case 1; use sample reference `ACC-1039` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "account=ACC-1039,balance=25000,status=active"

pattern = r"(?P<key>\w+)=(?P<value>[^,]+)"

pairs = re.findall(pattern, text)

result = dict(pairs)

print(result)

# %% [markdown]
# ### Q40. Use lookahead for strong fee waiver tokens for banking case 1; use sample reference `ACC-1040` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

tokens = [
    "FEEWAIVE10",
    "FEEWAIVE25",
    "FEEWAIVE99",
    "FEE10"
]

pattern = r"(?=FEEWAIVE)(?:[A-Z]+)(?:\d{2})"

for token in tokens:
    if re.fullmatch(pattern, token):
        print(token, "-> Valid strong fee-waiver token")
    else:
        print(token, "-> Invalid")
# Out:
# FEEWAIVE10 -> Valid strong fee-waiver token
# FEEWAIVE25 -> Valid strong fee-waiver token
# FEEWAIVE99 -> Valid strong fee-waiver token
# FEE10 -> Invalid

# %% [markdown]
# ### Q41. Use negative lookahead to reject test account references for banking case 1; use sample reference `ACC-1041` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

references = [
    "ACC-1041",
    "ACC-2001",
    "TEST-ACC-3001",
    "ACC-9999"
]

pattern = r"^(?!TEST-)\bACC-\d{4}\b$"

for reference in references:
    if re.fullmatch(pattern, reference):
        print(reference, "-> Accepted")
    else:
        print(reference, "-> Rejected")
# Out:
# ACC-1041 -> Accepted
# ACC-2001 -> Accepted
# TEST-ACC-3001 -> Rejected
# ACC-9999 -> Accepted

# %% [markdown]
# ### Q42. Extract account names between delimiters for banking case 1; use sample reference `ACC-1042` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Account [Savings] was opened, and account [Current] was updated."

pattern = r"\[([^\]]+)\]"

account_names = re.findall(pattern, text)

print("Account names:", account_names)
# Out:
# Account names: ['Savings', 'Current']

# %% [markdown]
# ### Q43. Replace dates with iso format for banking case 1; use sample reference `ACC-1043` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Transactions occurred on 15/08/2026 and 31/08/2026."

pattern = r"\b(\d{2})/(\d{2})/(\d{4})\b"

result = re.sub(pattern, r"\3-\2-\1", text)

print(result)
# Out:
# Transactions occurred on 2026-08-15 and 2026-08-31.

# %% [markdown]
# ### Q44. Compile a reusable account pattern for banking case 1; use sample reference `ACC-1044` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

account_pattern = re.compile(r"\bACC-\d{4}\b")

texts = [
    "Account ACC-1044 was opened.",
    "Transfer from ACC-2001 to ACC-3002.",
    "Invalid reference BANK-1000."
]

for text in texts:
    matches = account_pattern.findall(text)
    print(text)
    print("Matches:", matches)
# Out:
# Account ACC-1044 was opened.
# Matches: ['ACC-1044']
# Transfer from ACC-2001 to ACC-3002.
# Matches: ['ACC-2001', 'ACC-3002']
# Invalid reference BANK-1000.
# Matches: []

# %% [markdown]
# ### Q45. Use case-insensitive matching for brand search for banking case 1; use sample reference `ACC-1045` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Bank partners include HDFC, hdfc, Hdfc and ICICI."

pattern = re.compile(r"\bhdfc\b", re.IGNORECASE)

matches = pattern.findall(text)

print("Matches:", matches)
# Out:
# Matches: ['HDFC', 'hdfc', 'Hdfc']

# %% [markdown]
# ### Q46. Parse a receipt line into named groups for banking case 2; use sample reference `ACC-1046` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

receipt = "SAV123 | 4 | 1250.50"

pattern = re.compile(
    r"^(?P<account>[A-Z]{3}\d{3})\s*\|\s*"
    r"(?P<quantity>\d+)\s*\|\s*"
    r"(?P<amount>\d+(?:\.\d{2})?)$"
)

match = pattern.fullmatch(receipt)

if match:
    print(match.groupdict())
else:
    print("Invalid receipt")
# Out:
# {'account': 'SAV123', 'quantity': '4', 'amount': '1250.50'}

# %% [markdown]
# ### Q47. Validate an account reference with optional category prefix for banking case 2; use sample reference `ACC-1047` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

pattern = r"(?:SAV-|CUR-)?ACC-\d{4}"

references = [
    "ACC-1047",
    "SAV-ACC-1047",
    "CUR-ACC-1047",
    "LOAN-ACC-1047"
]

for reference in references:
    if re.fullmatch(pattern, reference):
        print(reference, "-> Valid")
    else:
        print(reference, "-> Invalid")
# Out:
# ACC-1047 -> Valid
# SAV-ACC-1047 -> Valid
# CUR-ACC-1047 -> Valid
# LOAN-ACC-1047 -> Invalid

# %% [markdown]
# ### Q48. Extract currency and amount for banking case 2; use sample reference `ACC-1048` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Payment received: ₹12500.50"

pattern = r"(?P<currency>₹|\$|€|£)\s*(?P<amount>\d+(?:\.\d{2})?)"

match = re.search(pattern, text)

if match:
    print("Currency:", match.group("currency"))
    print("Amount:", match.group("amount"))
else:
    print("No amount found")
# Out:
# Currency: ₹
# Amount: 12500.50

# %% [markdown]
# ### Q49. Normalize account holder phone numbers for banking case 2; use sample reference `ACC-1049` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

phones = [
    "+91 98765 43210",
    "09876543210",
    "98765-43210",
    "+91-98765-43210"
]

for phone in phones:
    normalized = re.sub(r"\D", "", phone)

    if normalized.startswith("91") and len(normalized) == 12:
        normalized = normalized[2:]

    elif normalized.startswith("0") and len(normalized) == 11:
        normalized = normalized[1:]

    print(phone, "->", normalized)
# Out:
# +91 98765 43210 -> 9876543210
# 09876543210 -> 9876543210
# 98765-43210 -> 9876543210
# +91-98765-43210 -> 9876543210

# %% [markdown]
# ### Q50. Find repeated account words for banking case 2; use sample reference `ACC-1050` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "The account account was verified and the transfer transfer was completed."

pattern = r"\b(\w+)\s+\1\b"

matches = re.findall(pattern, text, re.IGNORECASE)

print("Repeated words:", matches)
# Out:
# Repeated words: ['account', 'transfer']

# %% [markdown]
# ### Q51. Validate fee waiver start and end anchors for banking case 2; use sample reference `ACC-1051` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

tokens = [
    "FEEWAIVE10",
    "FEEWAIVE25",
    "X-FEEWAIVE10",
    "FEEWAIVE10-EXTRA"
]

pattern = r"^FEEWAIVE\d{2}$"

for token in tokens:
    if re.fullmatch(pattern, token):
        print(token, "-> Valid")
    else:
        print(token, "-> Invalid")
# Out:
# FEEWAIVE10 -> Valid
# FEEWAIVE25 -> Valid
# X-FEEWAIVE10 -> Invalid
# FEEWAIVE10-EXTRA -> Invalid

# %% [markdown]
# ### Q52. Redact emails from support text for banking case 2; use sample reference `ACC-1052` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = """
Customer email: rahul@example.com
Support email: support@bank.com
"""

pattern = r"\b[\w.+-]+@[\w.-]+\.[A-Za-z]{2,}\b"

redacted = re.sub(
    pattern,
    "[REDACTED_EMAIL]",
    text
)

print(redacted)
# Out:
# Customer email: [REDACTED_EMAIL]
# Support email: [REDACTED_EMAIL]

# %% [markdown]
# ### Q53. Extract transfer ids without partial matches for banking case 2; use sample reference `ACC-1053` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = """
Transfer TR-1001 completed.
Invalid XTR-1002 text.
Transfer TR-2030 completed.
"""

pattern = r"\bTR-\d{4}\b"

matches = re.findall(pattern, text)

print("Transfer IDs:", matches)
# Out:
# Transfer IDs: ['TR-1001', 'TR-2030']

# %% [markdown]
# ### Q54. Parse inventory key-value pairs for banking case 2; use sample reference `ACC-1054` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "account=ACC-1054,balance=25000,status=active"

pattern = r"(?P<key>\w+)=(?P<value>[^,]+)"

pairs = re.findall(pattern, text)

inventory = dict(pairs)

print(inventory)
# Out:
# {'account': 'ACC-1054', 'balance': '25000', 'status': 'active'}

# %% [markdown]
# ### Q55. Use lookahead for strong fee waiver tokens for banking case 2; use sample reference `ACC-1055` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

tokens = [
    "FEEWAIVE10",
    "FEEWAIVE25",
    "FEEWAIVE99",
    "FEE10"
]

pattern = r"(?=FEEWAIVE)[A-Z]+\d{2}"

for token in tokens:
    if re.fullmatch(pattern, token):
        print(token, "-> Valid")
    else:
        print(token, "-> Invalid")
# Out:
# FEEWAIVE10 -> Valid
# FEEWAIVE25 -> Valid
# FEEWAIVE99 -> Valid
# FEE10 -> Invalid

# %% [markdown]
# ### Q56. Use negative lookahead to reject test account references for banking case 2; use sample reference `ACC-1056` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

references = [
    "ACC-1056",
    "ACC-2500",
    "TEST-ACC-3000",
    "TEST-ACC-4500"
]

pattern = r"^(?!TEST-)\bACC-\d{4}\b$"

for reference in references:
    if re.fullmatch(pattern, reference):
        print(reference, "-> Accepted")
    else:
        print(reference, "-> Rejected")
# Out:
# ACC-1056 -> Accepted
# ACC-2500 -> Accepted
# TEST-ACC-3000 -> Rejected
# TEST-ACC-4500 -> Rejected

# %% [markdown]
# ### Q57. Extract account names between delimiters for banking case 2; use sample reference `ACC-1057` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Accounts [Savings] and [Current] are active."

pattern = r"\[([^\]]+)\]"

matches = re.findall(pattern, text)

print("Account names:", matches)
# Out:
# Account names: ['Savings', 'Current']

# %% [markdown]
# ### Q58. Replace dates with iso format for banking case 2; use sample reference `ACC-1058` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Dates: 10/08/2026 and 25/08/2026."

pattern = r"\b(\d{2})/(\d{2})/(\d{4})\b"

result = re.sub(
    pattern,
    r"\3-\2-\1",
    text
)

print(result)
# Out:
# Dates: 2026-08-10 and 2026-08-25.

# %% [markdown]
# ### Q59. Compile a reusable account pattern for banking case 2; use sample reference `ACC-1059` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

account_pattern = re.compile(r"\bACC-\d{4}\b")

texts = [
    "ACC-1059 created.",
    "Payment from ACC-2001.",
    "Accounts ACC-3002 and ACC-4003 were checked."
]

for text in texts:
    print("Text:", text)
    print("Matches:", account_pattern.findall(text))
# Out:
# Text: ACC-1059 created.
# Matches: ['ACC-1059']
# Text: Payment from ACC-2001.
# Matches: ['ACC-2001']
# Text: Accounts ACC-3002 and ACC-4003 were checked.
# Matches: ['ACC-3002', 'ACC-4003']

# %% [markdown]
# ### Q60. Use case-insensitive matching for brand search for banking case 2; use sample reference `ACC-1060` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Partners: HDFC, hdfc, HdfC, ICICI."

pattern = re.compile(
    r"\bhdfc\b",
    re.IGNORECASE
)

matches = pattern.findall(text)

print("HDFC matches:", matches)
# Out:
# HDFC matches: ['HDFC', 'hdfc', 'HdfC']

# %% [markdown]
# ### Q61. Parse a receipt line into named groups for banking case 3; use sample reference `ACC-1061` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

receipt = "SAV123 | 4 | 1250.50"

pattern = re.compile(
    r"^(?P<account>[A-Z]{3}\d{3})\s*\|\s*"
    r"(?P<quantity>\d+)\s*\|\s*"
    r"(?P<amount>\d+(?:\.\d{2})?)$"
)

match = pattern.fullmatch(receipt)

if match:
    print("Account:", match.group("account"))
    print("Quantity:", match.group("quantity"))
    print("Amount:", match.group("amount"))
    print("All data:", match.groupdict())
else:
    print("Invalid receipt")
# Out:
# Account: SAV123
# Quantity: 4
# Amount: 1250.50
# All data: {'account': 'SAV123', 'quantity': '4', 'amount': '1250.50'}

# %% [markdown]
# ### Q62. Validate an account reference with optional category prefix for banking case 3; use sample reference `ACC-1062` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

pattern = r"^(?:SAV-|CUR-)?ACC-\d{4}$"

references = [
    "ACC-1062",
    "SAV-ACC-1062",
    "CUR-ACC-1062",
    "LOAN-ACC-1062"
]

for reference in references:
    if re.fullmatch(pattern, reference):
        print(reference, "-> Valid")
    else:
        print(reference, "-> Invalid")
# Out:
# ACC-1062 -> Valid
# SAV-ACC-1062 -> Valid
# CUR-ACC-1062 -> Valid
# LOAN-ACC-1062 -> Invalid

# %% [markdown]
# ### Q63. Extract currency and amount for banking case 3; use sample reference `ACC-1063` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Transaction amount: ₹18500.75"

pattern = r"(?P<currency>₹|\$|€|£)\s*(?P<amount>\d+(?:\.\d{2})?)"

match = re.search(pattern, text)

if match:
    print("Currency:", match.group("currency"))
    print("Amount:", match.group("amount"))
else:
    print("No currency amount found")
# Out:
# Currency: ₹
# Amount: 18500.75

# %% [markdown]
# ### Q64. Normalize account holder phone numbers for banking case 3; use sample reference `ACC-1064` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

phones = [
    "+91 99887 76655",
    "09988776655",
    "99887-76655",
    "+91-99887-76655"
]

for phone in phones:
    normalized = re.sub(r"\D", "", phone)

    if normalized.startswith("91") and len(normalized) == 12:
        normalized = normalized[2:]

    elif normalized.startswith("0") and len(normalized) == 11:
        normalized = normalized[1:]

    print(phone, "->", normalized)
# Out:
# +91 99887 76655 -> 9988776655
# 09988776655 -> 9988776655
# 99887-76655 -> 9988776655
# +91-99887-76655 -> 9988776655

# %% [markdown]
# ### Q65. Find repeated account words for banking case 3; use sample reference `ACC-1065` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "The account account was opened and the balance balance was checked."

pattern = r"\b(\w+)\s+\1\b"

matches = re.findall(pattern, text, re.IGNORECASE)

print("Repeated words:", matches)
# Out:
# Repeated words: ['account', 'balance']

# %% [markdown]
# ### Q66. Validate fee waiver start and end anchors for banking case 3; use sample reference `ACC-1066` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

tokens = [
    "FEEWAIVE10",
    "FEEWAIVE25",
    "X-FEEWAIVE10",
    "FEEWAIVE10-EXTRA"
]

pattern = r"^FEEWAIVE\d{2}$"

for token in tokens:
    if re.fullmatch(pattern, token):
        print(token, "-> Valid")
    else:
        print(token, "-> Invalid")
# Out:
# FEEWAIVE10 -> Valid
# FEEWAIVE25 -> Valid
# X-FEEWAIVE10 -> Invalid
# FEEWAIVE10-EXTRA -> Invalid

# %% [markdown]
# ### Q67. Redact emails from support text for banking case 3; use sample reference `ACC-1067` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = """
Customer email: customer@example.com
Support email: help@bank.com
"""

pattern = r"\b[\w.+-]+@[\w.-]+\.[A-Za-z]{2,}\b"

redacted = re.sub(
    pattern,
    "[REDACTED_EMAIL]",
    text
)

print(redacted)
# Out:
# Customer email: [REDACTED_EMAIL]
# Support email: [REDACTED_EMAIL]

# %% [markdown]
# ### Q68. Extract transfer ids without partial matches for banking case 3; use sample reference `ACC-1068` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = """
Transfer TR-1068 completed.
Invalid XTR-2068 reference.
Transfer TR-3099 completed.
"""

pattern = r"\bTR-\d{4}\b"

matches = re.findall(pattern, text)

print("Transfer IDs:", matches)
# Out:
# Transfer IDs: ['TR-1068', 'TR-3099']

# %% [markdown]
# ### Q69. Parse inventory key-value pairs for banking case 3; use sample reference `ACC-1069` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "account=ACC-1069,balance=35000,status=active"

pattern = r"(?P<key>\w+)=(?P<value>[^,]+)"

pairs = re.findall(pattern, text)

result = dict(pairs)

print(result)
# Out:
# {'account': 'ACC-1069', 'balance': '35000', 'status': 'active'}

# %% [markdown]
# ### Q70. Use lookahead for strong fee waiver tokens for banking case 3; use sample reference `ACC-1070` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

tokens = [
    "FEEWAIVE10",
    "FEEWAIVE50",
    "FEEWAIVE99",
    "FEE10"
]

pattern = r"(?=FEEWAIVE)[A-Z]+\d{2}"

for token in tokens:
    if re.fullmatch(pattern, token):
        print(token, "-> Valid")
    else:
        print(token, "-> Invalid")
# Out:
# FEEWAIVE10 -> Valid
# FEEWAIVE50 -> Valid
# FEEWAIVE99 -> Valid
# FEE10 -> Invalid

# %% [markdown]
# ---
#
# ## Difficult
#
# Architecture, edge cases, and end-to-end banking systems.

# %% [markdown]
# ### Q71. Tokenize a messy receipt safely for banking case 1; use sample reference `ACC-1071` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

receipt = "ACC-1071 | Deposit: ₹15000.50 | Date: 31/08/2026"

pattern = re.compile(
    r"""
    (?P<account>ACC-\d{4})
    \s*\|\s*
    (?P<transaction>[A-Za-z]+)
    :
    \s*
    (?P<currency>₹|\$|€|£)
    \s*
    (?P<amount>\d+(?:\.\d{2})?)
    \s*\|\s*
    Date:
    \s*
    (?P<date>\d{2}/\d{2}/\d{4})
    """,
    re.VERBOSE
)

match = pattern.fullmatch(receipt)

if match:
    print(match.groupdict())
else:
    print("Invalid receipt format")
# Out:
# {'account': 'ACC-1071', 'transaction': 'Deposit', 'currency': '₹', 'amount': '15000.50', 'date': '31/08/2026'}

# %% [markdown]
# ### Q72. Validate a multi-part warehouse location for banking case 1; use sample reference `ACC-1072` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

locations = [
    "BLR-WH-01",
    "MUM-WH-25",
    "DEL-WH-99",
    "BLR-STORE-01"
]

pattern = r"^[A-Z]{3}-WH-\d{2}$"

for location in locations:
    if re.fullmatch(pattern, location):
        print(location, "-> Valid")
    else:
        print(location, "-> Invalid")
# Out:
# BLR-WH-01 -> Valid
# MUM-WH-25 -> Valid
# DEL-WH-99 -> Valid
# BLR-STORE-01 -> Invalid

# %% [markdown]
# ### Q73. Extract nested-looking account annotations within a defined limit for banking case 1; use sample reference `ACC-1073` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Account annotation: [[ACC-1073|VIP]]"

pattern = r"\[\[(ACC-\d{4}\|[A-Za-z]+)\]\]"

match = re.search(pattern, text)

if match:
    print("Annotation:", match.group(1))
else:
    print("No valid annotation found")
# Out:
# Annotation: ACC-1073|VIP

# %% [markdown]
# ### Q74. Find duplicate adjacent account reference tokens with backreferences for banking case 1; use sample reference `ACC-1074` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = """
ACC-1074 ACC-1074
ACC-2001 ACC-3001
ACC-5555 ACC-5555
"""

pattern = r"\b(ACC-\d{4})\s+\1\b"

matches = re.findall(pattern, text)

print("Duplicate account references:", matches)
# Out:
# Duplicate account references: ['ACC-1074', 'ACC-5555']

# %% [markdown]
# ### Q75. Redact card-like numbers while preserving last four digits for banking case 1; use sample reference `ACC-1075` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = """
Card: 4532-1234-5678-9012
Backup card: 5212 8765 4321 3456
"""

pattern = r"\b(?:\d{4}[- ]?){3}(\d{4})\b"

def mask_card(match):
    return "****-****-****-" + match.group(1)

result = re.sub(pattern, mask_card, text)

print(result)
# Out:
# Card: ****-****-****-9012
# Backup card: ****-****-****-3456

# %% [markdown]
# ### Q76. Parse audit log entries with named groups for banking case 1; use sample reference `ACC-1076` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

log = "2026-08-31 14:35:22 | ACC-1076 | WITHDRAW | 5000"

pattern = re.compile(
    r"^(?P<date>\d{4}-\d{2}-\d{2})\s+"
    r"(?P<time>\d{2}:\d{2}:\d{2})\s*\|\s*"
    r"(?P<account>ACC-\d{4})\s*\|\s*"
    r"(?P<action>[A-Z]+)\s*\|\s*"
    r"(?P<amount>\d+(?:\.\d{2})?)$"
)

match = pattern.fullmatch(log)

if match:
    print(match.groupdict())
else:
    print("Invalid audit log")
# Out:
# {'date': '2026-08-31', 'time': '14:35:22', 'account': 'ACC-1076', 'action': 'WITHDRAW', 'amount': '5000'}

# %% [markdown]
# ### Q77. Build a verbose-mode pattern for account holder ids for banking case 1; use sample reference `ACC-1077` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

pattern = re.compile(
    r"""
    ^
    (?P<prefix>CUST)      # fixed prefix
    -
    (?P<id>\d{4})         # four-digit ID
    $
    """,
    re.VERBOSE
)

ids = [
    "CUST-1077",
    "CUST-2045",
    "USER-1077",
    "CUST-77"
]

for value in ids:
    match = pattern.fullmatch(value)

    if match:
        print(value, "->", match.groupdict())
    else:
        print(value, "-> Invalid")
# Out:
# CUST-1077 -> {'prefix': 'CUST', 'id': '1077'}
# CUST-2045 -> {'prefix': 'CUST', 'id': '2045'}
# USER-1077 -> Invalid
# CUST-77 -> Invalid

# %% [markdown]
# ### Q78. Avoid catastrophic backtracking in a interest offer pattern for banking case 1; use sample reference `ACC-1078` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

# Risky style:
# pattern = re.compile(r"(A+)+B")

# Safer pattern:
pattern = re.compile(r"A+B")

samples = [
    "AAAAAB",
    "AAAAAAAAAAB",
    "AAAAAC"
]

for sample in samples:
    if pattern.fullmatch(sample):
        print(sample, "-> Valid")
    else:
        print(sample, "-> Invalid")
# Out:
# AAAAAB -> Valid
# AAAAAAAAAAB -> Valid
# AAAAAC -> Invalid

# %% [markdown]
# ### Q79. Validate amount formats across supported currencies for banking case 1; use sample reference `ACC-1079` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

amounts = [
    "₹1000",
    "₹1000.50",
    "$2500",
    "$2500.75",
    "€300",
    "£450.25",
    "USD 1000",
    "₹1000.123"
]

pattern = r"(?:₹|\$|€|£)\d+(?:\.\d{2})?"

for value in amounts:
    if re.fullmatch(pattern, value):
        print(value, "-> Valid")
    else:
        print(value, "-> Invalid")
# Out:
# ₹1000 -> Valid
# ₹1000.50 -> Valid
# $2500 -> Valid
# $2500.75 -> Valid
# €300 -> Valid
# £450.25 -> Valid
# USD 1000 -> Invalid
# ₹1000.123 -> Invalid

# %% [markdown]
# ### Q80. Create a regex-based data quality report for banking case 1; use sample reference `ACC-1080` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

accounts = [
    "ACC-1080",
    "ACC-2045",
    "ACC-9999",
    "BANK-1234",
    "ACC-12",
    "ACC-ABCD",
    "ACC-5000"
]

pattern = re.compile(r"^ACC-\d{4}$")

valid = []
invalid = []

for account in accounts:
    if pattern.fullmatch(account):
        valid.append(account)
    else:
        invalid.append(account)

total = len(accounts)
valid_count = len(valid)
invalid_count = len(invalid)

report = {
    "total_records": total,
    "valid_records": valid_count,
    "invalid_records": invalid_count,
    "valid_percentage": round(valid_count / total * 100, 2),
    "invalid_percentage": round(invalid_count / total * 100, 2),
    "valid_values": valid,
    "invalid_values": invalid
}

print("Data Quality Report")
print("-------------------")

for key, value in report.items():
    print(f"{key}: {value}")
# Out:
# Data Quality Report
# -------------------
# total_records: 7
# valid_records: 4
# invalid_records: 3
# valid_percentage: 57.14
# invalid_percentage: 42.86
# valid_values: ['ACC-1080', 'ACC-2045', 'ACC-9999', 'ACC-5000']
# invalid_values: ['BANK-1234', 'ACC-12', 'ACC-ABCD']

# %% [markdown]
# ### Q81. Tokenize a messy receipt safely for banking case 2; use sample reference `ACC-1081` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

receipt = "ACC-1081   |  3  |  ₹1500.50   |  Grocery"

# Split on whitespace around |
tokens = [part.strip() for part in re.split(r"\s*\|\s*", receipt)]

print(tokens)
# Out:
# ['ACC-1081', '3', '₹1500.50', 'Grocery']

# %% [markdown]
# ### Q82. Validate a multi-part warehouse location for banking case 2; use sample reference `ACC-1082` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

location = "DEL-WH-08"

pattern = r"[A-Z]{3}-WH-\d{2}"

if re.fullmatch(pattern, location):
    print("Valid warehouse location")
else:
    print("Invalid warehouse location")
# Out:
# Valid warehouse location

# %% [markdown]
# ### Q83. Extract nested-looking account annotations within a defined limit for banking case 2; use sample reference `ACC-1083` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Customer note: [[ACC-1083|Savings]] pending verification."

pattern = r"\[\[(ACC-\d{4}\|[A-Za-z]+)\]\]"

matches = re.findall(pattern, text)

print(matches)
# Out:
# ['ACC-1083|Savings']

# %% [markdown]
# ### Q84. Find duplicate adjacent account reference tokens with backreferences for banking case 2; use sample reference `ACC-1084` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Transfer ACC-1084 ACC-1084 was repeated."

pattern = r"\b(ACC-\d{4})\s+\1\b"

matches = re.findall(pattern, text)

print(matches)
# Out:
# ['ACC-1084']

# %% [markdown]
# ### Q85. Redact card-like numbers while preserving last four digits for banking case 2; use sample reference `ACC-1085` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Card used: 4111-2222-3333-4444"

pattern = r"\b(?:\d{4}[- ]?){3}(\d{4})\b"

def mask_card(match):
    last_four = match.group(1)
    return "****-****-****-" + last_four

result = re.sub(pattern, mask_card, text)

print(result)
# Out:
# Card used: ****-****-****-4444

# %% [markdown]
# ### Q86. Parse audit log entries with named groups for banking case 2; use sample reference `ACC-1086` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

log = "2026-08-15 14:30 | ACC-1086 | TRANSFER | SUCCESS"

pattern = re.compile(
    r"(?P<date>\d{4}-\d{2}-\d{2})\s+"
    r"(?P<time>\d{2}:\d{2})\s*\|\s*"
    r"(?P<account>ACC-\d{4})\s*\|\s*"
    r"(?P<action>\w+)\s*\|\s*"
    r"(?P<status>\w+)"
)

match = pattern.fullmatch(log)

if match:
    print(match.groupdict())
else:
    print("Invalid log")
# Out:
# {'date': '2026-08-15', 'time': '14:30', 'account': 'ACC-1086', 'action': 'TRANSFER', 'status': 'SUCCESS'}

# %% [markdown]
# ### Q87. Build a verbose-mode pattern for account holder ids for banking case 2; use sample reference `ACC-1087` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

holder_id = "AH-1087-IND"

pattern = re.compile(
    r"""
    ^
    (?P<prefix>AH)      # Account holder prefix
    -
    (?P<id>\d{4})       # Four digits
    -
    (?P<country>[A-Z]{3})  # Three-letter country code
    $
    """,
    re.VERBOSE
)

match = pattern.fullmatch(holder_id)

if match:
    print(match.groupdict())
else:
    print("Invalid account holder ID")
# Out:
# {'prefix': 'AH', 'id': '1087', 'country': 'IND'}

# %% [markdown]
# ### Q88. Avoid catastrophic backtracking in a interest offer pattern for banking case 2; use sample reference `ACC-1088` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

offer = "INTEREST-OFFER-7"

# Safer pattern: fixed structure
pattern = r"^INTEREST-OFFER-\d+$"

if re.fullmatch(pattern, offer):
    print("Valid interest offer")
else:
    print("Invalid interest offer")
# Out:
# Valid interest offer

# %% [markdown]
# ### Q89. Validate amount formats across supported currencies for banking case 2; use sample reference `ACC-1089` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

amounts = [
    "₹1500.50",
    "$250.00",
    "€99.99",
    "£75"
]

pattern = r"(?:₹|\$|€|£)\d+(?:\.\d{2})?"

for amount in amounts:
    if re.fullmatch(pattern, amount):
        print(amount, "-> Valid")
    else:
        print(amount, "-> Invalid")
# Out:
# ₹1500.50 -> Valid
# $250.00 -> Valid
# €99.99 -> Valid
# £75 -> Valid

# %% [markdown]
# ### Q90. Create a regex-based data quality report for banking case 2; use sample reference `ACC-1090` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

accounts = [
    "ACC-1090",
    "ACC-1234",
    "ACC-12",
    "ACC-5678",
    "abc-9999"
]

pattern = r"ACC-\d{4}"

valid = []
invalid = []

for account in accounts:
    if re.fullmatch(pattern, account):
        valid.append(account)
    else:
        invalid.append(account)

total = len(accounts)
quality = (len(valid) / total) * 100

print("Valid:", valid)
print("Invalid:", invalid)
print(f"Data quality: {quality:.2f}%")
# Out:
# Valid: ['ACC-1090', 'ACC-1234', 'ACC-5678']
# Invalid: ['ACC-12', 'abc-9999']
# Data quality: 60.00%

# %% [markdown]
# ### Q91. Tokenize a messy receipt safely for banking case 3; use sample reference `ACC-1091` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

receipt = "ACC-1091 | 5 | ₹2750.00 | Electronics"

tokens = [part.strip() for part in re.split(r"\s*\|\s*", receipt)]

print(tokens)
# Out:
# ['ACC-1091', '5', '₹2750.00', 'Electronics']

# %% [markdown]
# ### Q92. Validate a multi-part warehouse location for banking case 3; use sample reference `ACC-1092` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

location = "BLR-WH-12"

pattern = r"[A-Z]{3}-WH-\d{2}"

if re.fullmatch(pattern, location):
    print("Valid warehouse location")
else:
    print("Invalid warehouse location")
# Out:
# Valid warehouse location

# %% [markdown]
# ### Q93. Extract nested-looking account annotations within a defined limit for banking case 3; use sample reference `ACC-1093` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Audit note: [[ACC-1093|Current]] requires review."

pattern = r"\[\[(ACC-\d{4}\|[A-Za-z]+)\]\]"

matches = re.findall(pattern, text)

print(matches)
# Out:
# ['ACC-1093|Current']

# %% [markdown]
# ### Q94. Find duplicate adjacent account reference tokens with backreferences for banking case 3; use sample reference `ACC-1094` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Review ACC-1094 ACC-1094 before approval."

pattern = r"\b(ACC-\d{4})\s+\1\b"

matches = re.findall(pattern, text)

print(matches)
# Out:
# ['ACC-1094']

# %% [markdown]
# ### Q95. Redact card-like numbers while preserving last four digits for banking case 3; use sample reference `ACC-1095` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

text = "Payment card: 5555 6666 7777 8888"

pattern = r"\b(?:\d{4}[- ]?){3}(\d{4})\b"

def mask_card(match):
    return "****-****-****-" + match.group(1)

result = re.sub(pattern, mask_card, text)

print(result)
# Out:
# Payment card: ****-****-****-8888

# %% [markdown]
# ### Q96. Parse audit log entries with named groups for banking case 3; use sample reference `ACC-1096` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

log = "2026-09-01 18:45 | ACC-1096 | LOGIN | FAILED"

pattern = re.compile(
    r"(?P<date>\d{4}-\d{2}-\d{2})\s+"
    r"(?P<time>\d{2}:\d{2})\s*\|\s*"
    r"(?P<account>ACC-\d{4})\s*\|\s*"
    r"(?P<action>\w+)\s*\|\s*"
    r"(?P<status>\w+)"
)

match = pattern.fullmatch(log)

if match:
    print(match.groupdict())
else:
    print("Invalid log")
# Out:
# {'date': '2026-09-01', 'time': '18:45', 'account': 'ACC-1096', 'action': 'LOGIN', 'status': 'FAILED'}

# %% [markdown]
# ### Q97. Build a verbose-mode pattern for account holder ids for banking case 3; use sample reference `ACC-1097` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

holder_id = "AH-1097-IND"

pattern = re.compile(
    r"""
    ^
    (?P<prefix>AH)
    -
    (?P<id>\d{4})
    -
    (?P<country>[A-Z]{3})
    $
    """,
    re.VERBOSE
)

match = pattern.fullmatch(holder_id)

if match:
    print(match.groupdict())
else:
    print("Invalid account holder ID")
# Out:
# {'prefix': 'AH', 'id': '1097', 'country': 'IND'}

# %% [markdown]
# ### Q98. Avoid catastrophic backtracking in a interest offer pattern for banking case 3; use sample reference `ACC-1098` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

offer = "INTEREST-OFFER-10"

# Constrained pattern
pattern = r"^INTEREST-OFFER-\d+$"

match = re.fullmatch(pattern, offer)

if match:
    print("Valid interest offer")
else:
    print("Invalid interest offer")
# Out:
# Valid interest offer

# %% [markdown]
# ### Q99. Validate amount formats across supported currencies for banking case 3; use sample reference `ACC-1099` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

amounts = [
    "₹5000.00",
    "$125.50",
    "€80.25",
    "£100"
]

pattern = r"(?:₹|\$|€|£)\d+(?:\.\d{2})?"

for amount in amounts:
    result = bool(re.fullmatch(pattern, amount))
    print(amount, "->", "Valid" if result else "Invalid")
# Out:
# ₹5000.00 -> Valid
# $125.50 -> Valid
# €80.25 -> Valid
# £100 -> Valid

# %% [markdown]
# ### Q100. Create a regex-based data quality report for banking case 3; use sample reference `ACC-1100` and explain the result.
#
# **Hints**
#
# 1. Write representative valid and invalid samples before writing the pattern.
# 2. Use raw strings, named groups for extraction, and `fullmatch` for whole-field validation.
# 3. Never treat regex alone as authorization or full semantic validation; verify dates and checksums separately.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import re

accounts = [
    "ACC-1100",
    "ACC-2222",
    "ACC-33",
    "ACC-9999",
    "XYZ-1234"
]

pattern = r"ACC-\d{4}"

valid = []
invalid = []

for account in accounts:
    if re.fullmatch(pattern, account):
        valid.append(account)
    else:
        invalid.append(account)

total = len(accounts)
valid_count = len(valid)
invalid_count = len(invalid)

quality_percentage = (valid_count / total) * 100

report = {
    "total_records": total,
    "valid_records": valid_count,
    "invalid_records": invalid_count,
    "quality_percentage": round(quality_percentage, 2),
    "valid": valid,
    "invalid": invalid
}

print(report)
# Out:
# {'total_records': 5, 'valid_records': 3, 'invalid_records': 2, 'quality_percentage': 60.0, 'valid': ['ACC-1100', 'ACC-2222', 'ACC-9999'], 'invalid': ['ACC-33', 'XYZ-1234']}
